# %% [markdown]
# # Digital Divide Predictor - Aadhaar Analysis
# ## Step 1: Load and Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Load all 3 datasets
enrolment = pd.read_csv('api_data_aadhar_enrolment/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv')
demographic = pd.read_csv('api_data_aadhar_demographic/api_data_aadhar_demographic/api_data_aadhar_demographic_0_500000.csv')
biometric = pd.read_csv('api_data_aadhar_biometric/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000.csv')

# Check the columns in each dataset
print("=" * 60)
print("ENROLMENT COLUMNS:")
print("=" * 60)
print(enrolment.columns.tolist())
print(f"\nShape: {enrolment.shape}")
print(f"\nFirst few rows:")
print(enrolment.head(3))

print("\n" + "=" * 60)
print("DEMOGRAPHIC COLUMNS:")
print("=" * 60)
print(demographic.columns.tolist())
print(f"\nShape: {demographic.shape}")
print(f"\nFirst few rows:")
print(demographic.head(3))

print("\n" + "=" * 60)
print("BIOMETRIC COLUMNS:")
print("=" * 60)
print(biometric.columns.tolist())
print(f"\nShape: {biometric.shape}")
print(f"\nFirst few rows:")
print(biometric.head(3))
